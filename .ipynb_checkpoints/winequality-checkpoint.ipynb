# %%
import sagemaker
import boto3
import os 
 
bucket = sagemaker.Session().default_bucket()                     
prefix = 'sagemaker/xgboost-winequality'

# Role when working on a notebook instance
role = sagemaker.get_execution_role()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-1-cdd31cb9c255> in <module>
# ----> 1 import sagemaker
#       2 import boto3
#       3 import os
#       4
#       5 bucket = sagemaker.Session().default_bucket()
#
# ModuleNotFoundError: No module named 'sagemaker'

# %%
# !wget -N https://archive.ics.uci.edu/ml/machine-learning-databases/wine-quality/winequality-red.csv
# Out:
# --2020-11-21 19:15:45--  https://archive.ics.uci.edu/ml/machine-learning-databases/wine-quality/winequality-red.csv
# Resolving archive.ics.uci.edu (archive.ics.uci.edu)... 128.195.10.252
# Connecting to archive.ics.uci.edu (archive.ics.uci.edu)|128.195.10.252|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 84199 (82K) [application/x-httpd-php]
# Saving to: ‘winequality-red.csv’
#
# winequality-red.csv 100%[===================>]  82.23K  81.6KB/s    in 1.0s
#
# 2020-11-21 19:15:47 (81.6 KB/s) - ‘winequality-red.csv’ saved [84199/84199]

# %%
# !wget -N https://archive.ics.uci.edu/ml/machine-learning-databases/wine-quality/winequality-white.csv
# Out:
# --2020-11-21 19:16:00--  https://archive.ics.uci.edu/ml/machine-learning-databases/wine-quality/winequality-white.csv
# Resolving archive.ics.uci.edu (archive.ics.uci.edu)... 128.195.10.252
# Connecting to archive.ics.uci.edu (archive.ics.uci.edu)|128.195.10.252|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 264426 (258K) [application/x-httpd-php]
# Saving to: ‘winequality-white.csv’
#
# winequality-white.c 100%[===================>] 258.23K  77.6KB/s    in 3.3s
#
# 2020-11-21 19:16:04 (77.6 KB/s) - ‘winequality-white.csv’ saved [264426/264426]

# %%
# !head winequality-red.csv
# Out:
# "fixed acidity";"volatile acidity";"citric acid";"residual sugar";"chlorides";"free sulfur dioxide";"total sulfur dioxide";"density";"pH";"sulphates";"alcohol";"quality"
# 7.4;0.7;0;1.9;0.076;11;34;0.9978;3.51;0.56;9.4;5
# 7.8;0.88;0;2.6;0.098;25;67;0.9968;3.2;0.68;9.8;5
# 7.8;0.76;0.04;2.3;0.092;15;54;0.997;3.26;0.65;9.8;5
# 11.2;0.28;0.56;1.9;0.075;17;60;0.998;3.16;0.58;9.8;6
# 7.4;0.7;0;1.9;0.076;11;34;0.9978;3.51;0.56;9.4;5
# 7.4;0.66;0;1.8;0.075;13;40;0.9978;3.51;0.56;9.4;5
# 7.9;0.6;0.06;1.6;0.069;15;59;0.9964;3.3;0.46;9.4;5
# 7.3;0.65;0;1.2;0.065;15;21;0.9946;3.39;0.47;10;7
# 7.8;0.58;0.02;2;0.073;9;18;0.9968;3.36;0.57;9.5;7

# %%
# !head winequality-white.csv
# Out:
# "fixed acidity";"volatile acidity";"citric acid";"residual sugar";"chlorides";"free sulfur dioxide";"total sulfur dioxide";"density";"pH";"sulphates";"alcohol";"quality"
# 7;0.27;0.36;20.7;0.045;45;170;1.001;3;0.45;8.8;6
# 6.3;0.3;0.34;1.6;0.049;14;132;0.994;3.3;0.49;9.5;6
# 8.1;0.28;0.4;6.9;0.05;30;97;0.9951;3.26;0.44;10.1;6
# 7.2;0.23;0.32;8.5;0.058;47;186;0.9956;3.19;0.4;9.9;6
# 7.2;0.23;0.32;8.5;0.058;47;186;0.9956;3.19;0.4;9.9;6
# 8.1;0.28;0.4;6.9;0.05;30;97;0.9951;3.26;0.44;10.1;6
# 6.2;0.32;0.16;7;0.045;30;136;0.9949;3.18;0.47;9.6;6
# 7;0.27;0.36;20.7;0.045;45;170;1.001;3;0.45;8.8;6
# 6.3;0.3;0.34;1.6;0.049;14;132;0.994;3.3;0.49;9.5;6

# %%
import numpy as np  # For matrix operations and numerical processing
import pandas as pd # For munging tabular data

# %%
# https://pandas.pydata.org/pandas-docs/stable/generated/pandas.read_csv.html
data = pd.read_csv('winequality-red.csv', sep=';')
pd.set_option('display.max_columns', 500)     # Make sure we can see all of the columns
pd.set_option('display.max_rows', 50)         # Keep the output on one page
data[:] # Show the first 10 lines
np.max(data['quality'])
# Out:
#     fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0             7.4             0.700         0.00             1.9      0.076
# 1             7.8             0.880         0.00             2.6      0.098
# 2             7.8             0.760         0.04             2.3      0.092
# 3            11.2             0.280         0.56             1.9      0.075
# 4             7.4             0.700         0.00             1.9      0.076
# 5             7.4             0.660         0.00             1.8      0.075
# 6             7.9             0.600         0.06             1.6      0.069
# 7             7.3             0.650         0.00             1.2      0.065
# 8             7.8             0.580         0.02             2.0      0.073
# 9             7.5             0.500         0.36             6.1      0.071
# 10            6.7             0.580         0.08             1.8      0.097
# ...

# %%
# https://pandas.pydata.org/pandas-docs/stable/generated/pandas.read_csv.html
data = pd.read_csv('winequality-white.csv', sep=';')
pd.set_option('display.max_columns', 500)     # Make sure we can see all of the columns
pd.set_option('display.max_rows', 50)         # Keep the output on one page
data[:30]
# Out:
#     fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0             7.0              0.27         0.36           20.70      0.045
# 1             6.3              0.30         0.34            1.60      0.049
# 2             8.1              0.28         0.40            6.90      0.050
# 3             7.2              0.23         0.32            8.50      0.058
# 4             7.2              0.23         0.32            8.50      0.058
# 5             8.1              0.28         0.40            6.90      0.050
# 6             6.2              0.32         0.16            7.00      0.045
# 7             7.0              0.27         0.36           20.70      0.045
# 8             6.3              0.30         0.34            1.60      0.049
# 9             8.1              0.22         0.43            1.50      0.044
# 10            8.1              0.27         0.41            1.45      0.033
# ...

# %%
data.shape # (number of lines, number of columns)
# Out:
# (4898, 12)

# %%
one_class = data[data['quality']<=7]
one_class_count = one_class.shape[0]
print("Normal quality wines: %d" % one_class_count)

zero_class = data[data['quality']>=8]
zero_class_count = zero_class.shape[0]
print("Excellent Quality wines: %d" % zero_class_count)

zero_to_one_ratio = zero_class_count/one_class_count
print("Ratio: %.2f" % zero_to_one_ratio)
# Out:
# Normal quality wines: 4718
# Excellent Quality wines: 180
# Ratio: 0.04

# %%
[np.min(data['residual sugar']), np.max(data['residual sugar'])]
# Out:
# [0.6, 65.8]

# %%
#wines with very high residual sugar are low quality. wines with a balanced residual sugar are better quality

# %%
# Indicator variable to capture when residual sugar takes a value higher than 2.5
# https://docs.scipy.org/doc/numpy-1.15.1/reference/generated/numpy.where.html
data['very sweet'] = np.where(data['residual sugar'] >= 2.5, 1, 0)
data = data.drop(['residual sugar'], axis=1)

# %%
data['fixed acidity'].value_counts()
# Out:
# 6.80     308
# 6.60     290
# 6.40     280
# 6.90     241
# 6.70     236
#         ...
# 6.45       1
# 3.80       1
# 14.20      1
# 10.20      1
# 3.90       1
# Name: fixed acidity, Length: 68, dtype: int64

# %%
data['total sulfur dioxide'].value_counts()
# Out:
# 111.0    69
# 113.0    61
# 117.0    57
# 118.0    55
# 128.0    54
#          ..
# 10.0      1
# 44.0      1
# 313.0     1
# 19.0      1
# 234.5     1
# Name: total sulfur dioxide, Length: 251, dtype: int64

# %%
data['quality'].value_counts()
# Out:
# 6    2198
# 5    1457
# 7     880
# 8     175
# 4     163
# 3      20
# 9       5
# Name: quality, dtype: int64

# %%
# Indicator for excellent quality wine
# https://docs.scipy.org/doc/numpy-1.15.0/reference/generated/numpy.in1d.html
data['excellent wine'] = np.where(np.in1d(data['quality'], [8, 9]), 1, 0)

# %%
# https://pandas.pydata.org/pandas-docs/stable/generated/pandas.get_dummies.html
model_data = pd.get_dummies(data)  # Convert categorical variables to sets of indicators
model_data[:30]
# Out:
#     fixed acidity  volatile acidity  citric acid  chlorides  \
# 0             7.0              0.27         0.36      0.045
# 1             6.3              0.30         0.34      0.049
# 2             8.1              0.28         0.40      0.050
# 3             7.2              0.23         0.32      0.058
# 4             7.2              0.23         0.32      0.058
# 5             8.1              0.28         0.40      0.050
# 6             6.2              0.32         0.16      0.045
# 7             7.0              0.27         0.36      0.045
# 8             6.3              0.30         0.34      0.049
# 9             8.1              0.22         0.43      0.044
# 10            8.1              0.27         0.41      0.033
# 11            8.6              0.23         0.40      0.035
# 12            7.9              0.18         0.37      0.040
# 13            6.6              0.16         0.40      0.044
# 14            8.3              0.42         0.62      0.040
# ...

# %%
model_data.shape
# Out:
# (4898, 13)

# %%
data['pH'].value_counts()
# Out:
# 3.14    172
# 3.16    164
# 3.22    146
# 3.19    145
# 3.18    138
#        ...
# 3.79      1
# 2.84      1
# 2.74      1
# 3.81      1
# 2.82      1
# Name: pH, Length: 103, dtype: int64

# %%
model_data.shape
# Out:
# (4898, 13)

# %%
# Set the seed to 123 for reproductibility
# https://pandas.pydata.org/pandas-docs/version/0.22/generated/pandas.DataFrame.sample.html
# https://docs.scipy.org/doc/numpy-1.15.1/reference/generated/numpy.split.html
train_data, validation_data, test_data = np.split(model_data.sample(frac=1, random_state=123), 
                                                  [int(0.7 * len(model_data)), int(0.9*len(model_data))])  

# Drop the two columns for 'yes' and 'no' and add 'yes' back as first column of the dataframe
# https://pandas.pydata.org/pandas-docs/stable/generated/pandas.concat.html
pd.concat([train_data['excellent wine'], train_data.drop(['quality', 'excellent wine'], axis=1)], axis=1).to_csv('train.csv', index=False, header=False)
pd.concat([validation_data['excellent wine'], validation_data.drop(['quality', 'excellent wine'], axis=1)], axis=1).to_csv('validation.csv', index=False, header=False)
#pd.concat([test_data['y_yes'], test_data.drop(['y_no', 'y_yes'], axis=1)], axis=1).to_csv('test.csv', index=False, header=False)

# Dropping the target value, as we will use the CSV file for batch transform
test_data.drop(['quality', 'excellent wine'], axis=1).to_csv('test.csv', index=False, header=False)

# %%
# !ls -l *.csv
# Out:
# -rw-r--r--  1 itsencrypted  staff   30033 Nov 21 20:29 test.csv
# -rw-r--r--  1 itsencrypted  staff  217365 Nov 21 20:29 train.csv
# -rw-r--r--  1 itsencrypted  staff   61322 Nov 21 20:29 validation.csv
# -rw-r--r--  1 itsencrypted  staff   84199 Oct 16  2009 winequality-red.csv
# -rw-r--r--  1 itsencrypted  staff  264426 Oct 16  2009 winequality-white.csv

# %%
boto3.Session().resource('s3').Bucket(bucket).Object(os.path.join(prefix, 'train/train.csv')).upload_file('train.csv')
boto3.Session().resource('s3').Bucket(bucket).Object(os.path.join(prefix, 'validation/validation.csv')).upload_file('validation.csv')
boto3.Session().resource('s3').Bucket(bucket).Object(os.path.join(prefix, 'test/test.csv')).upload_file('test.csv')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-53-13cdd2154845> in <module>
# ----> 1 boto3.Session().resource('s3').Bucket(bucket).Object(os.path.join(prefix, 'train/train.csv')).upload_file('train.csv')
#       2 boto3.Session().resource('s3').Bucket(bucket).Object(os.path.join(prefix, 'validation/validation.csv')).upload_file('validation.csv')
#       3 boto3.Session().resource('s3').Bucket(bucket).Object(os.path.join(prefix, 'test/test.csv')).upload_file('test.csv')
#
# NameError: name 'boto3' is not defined

# %%
s3_input_train = sagemaker.s3_input(s3_data='s3://{}/{}/train'.format(bucket, prefix), content_type='csv')
s3_input_validation = sagemaker.s3_input(s3_data='s3://{}/{}/validation/'.format(bucket, prefix), content_type='csv')

s3_data = {'train': s3_input_train, 'validation': s3_input_validation}
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-54-3110db147fad> in <module>
# ----> 1 s3_input_train = sagemaker.s3_input(s3_data='s3://{}/{}/train'.format(bucket, prefix), content_type='csv')
#       2 s3_input_validation = sagemaker.s3_input(s3_data='s3://{}/{}/validation/'.format(bucket, prefix), content_type='csv')
#       3
#       4 s3_data = {'train': s3_input_train, 'validation': s3_input_validation}
#
# NameError: name 'sagemaker' is not defined
